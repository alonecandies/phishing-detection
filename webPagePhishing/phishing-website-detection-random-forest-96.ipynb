# %% [markdown]
# dataset:
# https://www.kaggle.com/datasets/shashwatwork/web-page-phishing-detection-dataset

# %% [markdown]
# ### 1. import the dataset and libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         path = os.path.join(dirname, filename)

path = "./dataset_phishing.csv"
raw_dataset = pd.read_csv(path)

# %% [markdown]
# ### 2. inspect the dataset

# %%
raw_dataset.shape
# Out:
# (11430, 89)

# %%
raw_dataset.describe()
# Out:
#          length_url  length_hostname            ip       nb_dots
# count  11430.000000     11430.000000  11430.000000  11430.000000  \
# mean      61.126684        21.090289      0.150569      2.480752
# std       55.297318        10.777171      0.357644      1.369686
# min       12.000000         4.000000      0.000000      1.000000
# 25%       33.000000        15.000000      0.000000      2.000000
# 50%       47.000000        19.000000      0.000000      2.000000
# 75%       71.000000        24.000000      0.000000      3.000000
# max     1641.000000       214.000000      1.000000     24.000000
#
#          nb_hyphens         nb_at         nb_qm        nb_and    nb_or
# count  11430.000000  11430.000000  11430.000000  11430.000000  11430.0  \
# mean       0.997550      0.022222      0.141207      0.162292      0.0
# std        2.087087      0.155500      0.364456      0.821337      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# 25%        0.000000      0.000000      0.000000      0.000000      0.0
# 50%        0.000000      0.000000      0.000000      0.000000      0.0
# 75%        1.000000      0.000000      0.000000      0.000000      0.0
# max       43.000000      4.000000      3.000000     19.000000      0.0
#
#               nb_eq  ...   empty_title  domain_in_title
# count  11430.000000  ...  11430.000000     11430.000000  \
# mean       0.293176  ...      0.124759         0.775853
# std        0.998317  ...      0.330460         0.417038
# min        0.000000  ...      0.000000         0.000000
# 25%        0.000000  ...      0.000000         1.000000
# 50%        0.000000  ...      0.000000         1.000000
# 75%        0.000000  ...      0.000000         1.000000
# max       19.000000  ...      1.000000         1.000000
#
#        domain_with_copyright  whois_registered_domain
# count           11430.000000             11430.000000  \
# mean                0.439545                 0.072878
# std                 0.496353                 0.259948
# min                 0.000000                 0.000000
# 25%                 0.000000                 0.000000
# 50%                 0.000000                 0.000000
# 75%                 1.000000                 0.000000
# max                 1.000000                 1.000000
#
#        domain_registration_length    domain_age   web_traffic    dns_record
# count                11430.000000  11430.000000  1.143000e+04  11430.000000  \
# mean                   492.532196   4062.543745  8.567566e+05      0.020122
# std                    814.769415   3107.784600  1.995606e+06      0.140425
# min                     -1.000000    -12.000000  0.000000e+00      0.000000
# 25%                     84.000000    972.250000  0.000000e+00      0.000000
# 50%                    242.000000   3993.000000  1.651000e+03      0.000000
# 75%                    449.000000   7026.750000  3.738455e+05      0.000000
# max                  29829.000000  12874.000000  1.076799e+07      1.000000
#
#        google_index     page_rank
# count  11430.000000  11430.000000
# mean       0.533946      3.185739
# std        0.498868      2.536955
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        1.000000      3.000000
# 75%        1.000000      5.000000
# max        1.000000     10.000000
#
# [8 rows x 87 columns]

# %% [markdown]
# * outliers at max values: nb_dots, nb_hyphens, nb_at, nb_qm, nb_and,nb_eq, domain_registration_length, domain_age
# * target = legitimate/phishing

# %%
pd.set_option('display.max_rows', 500)
raw_dataset.isna().sum()
# no missing values
# Out:
# url                           0
# length_url                    0
# length_hostname               0
# ip                            0
# nb_dots                       0
# nb_hyphens                    0
# nb_at                         0
# nb_qm                         0
# nb_and                        0
# nb_or                         0
# nb_eq                         0
# nb_underscore                 0
# nb_tilde                      0
# nb_percent                    0
# nb_slash                      0
# nb_star                       0
# nb_colon                      0
# nb_comma                      0
# nb_semicolumn                 0
# nb_dollar                     0
# nb_space                      0
# nb_www                        0
# nb_com                        0
# nb_dslash                     0
# http_in_path                  0
# https_token                   0
# ratio_digits_url              0
# ratio_digits_host             0
# punycode                      0
# port                          0
# tld_in_path                   0
# tld_in_subdomain              0
# abnormal_subdomain            0
# nb_subdomains                 0
# prefix_suffix                 0
# random_domain                 0
# shortening_service            0
# path_extension                0
# nb_redirection                0
# nb_external_redirection       0
# length_words_raw              0
# char_repeat                   0
# shortest_words_raw            0
# shortest_word_host            0
# shortest_word_path            0
# longest_words_raw             0
# longest_word_host             0
# longest_word_path             0
# avg_words_raw                 0
# avg_word_host                 0
# avg_word_path                 0
# phish_hints                   0
# domain_in_brand               0
# brand_in_subdomain            0
# brand_in_path                 0
# suspecious_tld                0
# statistical_report            0
# nb_hyperlinks                 0
# ratio_intHyperlinks           0
# ratio_extHyperlinks           0
# ratio_nullHyperlinks          0
# nb_extCSS                     0
# ratio_intRedirection          0
# ratio_extRedirection          0
# ratio_intErrors               0
# ratio_extErrors               0
# login_form                    0
# external_favicon              0
# links_in_tags                 0
# submit_email                  0
# ratio_intMedia                0
# ratio_extMedia                0
# sfh                           0
# iframe                        0
# popup_window                  0
# safe_anchor                   0
# onmouseover                   0
# right_clic                    0
# empty_title                   0
# domain_in_title               0
# domain_with_copyright         0
# whois_registered_domain       0
# domain_registration_length    0
# domain_age                    0
# web_traffic                   0
# dns_record                    0
# google_index                  0
# page_rank                     0
# status                        0
# dtype: int64

# %%
pd.reset_option('display.max_rows')

# %%
original_dataset = raw_dataset.copy()

# %% [markdown]
# ##### 2.1 inspect correlation and determine important features

# %%
class_map = {'legitimate':0, 'phishing':1}
original_dataset['status'] = original_dataset['status'].map(class_map)

# %%
# remove index and url col
original_dataset = original_dataset.drop(['url'], axis=1)

# %%
corr_matrix = original_dataset.corr()

# %%
plt.figure(figsize=(60,60))
color = plt.get_cmap('viridis').copy()   # default color
color.set_bad('lightblue') 
sns.heatmap(corr_matrix, annot=True, linewidth=0.4, cmap=color)
plt.savefig('heatmap')
plt.show()

# %%
corr_matrix.shape
# Out:
# (88, 88)

# %%
corr_matrix['status']
#same as corr_matrix.iloc[[87]].T
# last column and last row are the same
# Out:
# length_url         0.248580
# length_hostname    0.238322
# ip                 0.321698
# nb_dots            0.207029
# nb_hyphens        -0.100107
#                      ...
# web_traffic        0.060388
# dns_record         0.122119
# google_index       0.731171
# page_rank         -0.511137
# status             1.000000
# Name: status, Length: 88, dtype: float64

# %%
status_corr = corr_matrix['status']
status_corr.shape
# Out:
# (88,)

# %%
def feature_selector_correlation(cmatrix, threshold):
    
    selected_features = []
    feature_score = []
    i=0
    for score in cmatrix:
        if abs(score)>threshold:
            selected_features.append(cmatrix.index[i])
            feature_score.append( ['{:3f}'.format(score)])
        i+=1
    result = list(zip(selected_features,feature_score)) 
    return result

# %%
features_selected = feature_selector_correlation(status_corr, 0.2)
features_selected
# Out:
# [('length_url', ['0.248580']),
#  ('length_hostname', ['0.238322']),
#  ('ip', ['0.321698']),
#  ('nb_dots', ['0.207029']),
#  ('nb_qm', ['0.294319']),
#  ('nb_eq', ['0.233386']),
#  ('nb_slash', ['0.242270']),
#  ('nb_www', ['-0.443468']),
#  ('ratio_digits_url', ['0.356395']),
#  ('ratio_digits_host', ['0.224335']),
#  ('tld_in_subdomain', ['0.208884']),
#  ('prefix_suffix', ['0.214681']),
#  ('shortest_word_host', ['0.223084']),
#  ('longest_words_raw', ['0.200147']),
#  ('longest_word_path', ['0.212709']),
#  ('phish_hints', ['0.335393']),
#  ('nb_hyperlinks', ['-0.342628']),
#  ('ratio_intHyperlinks', ['-0.243982']),
#  ('empty_title', ['0.207043']),
#  ('domain_in_title', ['0.342807']),
#  ('domain_age', ['-0.331889']),
#  ('google_index', ['0.731171']),
#  ('page_rank', ['-0.511137']),
#  ('status', ['1.000000'])]

# %% [markdown]
# ### 3. Preprocessing

# %% [markdown]
# #### 3.1 setup predictors and targets

# %%
selected_features = [i for (i,j) in features_selected if i != 'status']
selected_features.remove("domain_age")
# selected_features.remove("page_rank")
selected_features.remove("google_index")
selected_features
# Out:
# ['length_url',
#  'length_hostname',
#  'ip',
#  'nb_dots',
#  'nb_qm',
#  'nb_eq',
#  'nb_slash',
#  'nb_www',
#  'ratio_digits_url',
#  'ratio_digits_host',
#  'tld_in_subdomain',
#  'prefix_suffix',
#  'shortest_word_host',
#  'longest_words_raw',
#  'longest_word_path',
#  'phish_hints',
#  'nb_hyperlinks',
#  'ratio_intHyperlinks',
#  'empty_title',
#  'domain_in_title',
#  'page_rank']

# %%
X_selected = original_dataset[selected_features]
X_selected
# Out:
#        length_url  length_hostname  ip  nb_dots  nb_qm  nb_eq  nb_slash
# 0              37               19   0        3      0      0         3  \
# 1              77               23   1        1      0      0         5
# 2             126               50   1        4      1      3         5
# 3              18               11   0        2      0      0         2
# 4              55               15   0        2      0      0         5
# ...           ...              ...  ..      ...    ...    ...       ...
# 11425          45               17   0        2      0      0         4
# 11426          84               18   0        5      1      1         5
# 11427         105               16   1        2      1      1         5
# 11428          38               30   0        2      0      0         3
# 11429         477               14   1       24      1      9         4
#
#        nb_www  ratio_digits_url  ratio_digits_host  ...  prefix_suffix
# 0           1          0.000000           0.000000  ...              0  \
# 1           0          0.220779           0.000000  ...              0
# 2           0          0.150794           0.000000  ...              1
# 3           0          0.000000           0.000000  ...              0
# 4           1          0.000000           0.000000  ...              0
# ...       ...               ...                ...  ...            ...
# 11425       1          0.000000           0.000000  ...              0
# 11426       1          0.023810           0.000000  ...              0
# 11427       1          0.142857           0.000000  ...              0
# 11428       1          0.000000           0.000000  ...              0
# 11429       1          0.085954           0.785714  ...              0
#
#        shortest_word_host  longest_words_raw  longest_word_path  phish_hints
# 0                       3                 11                  6            0  \
# 1                      19                 32                 32            0
# 2                       3                 17                 17            0
# 3                       5                  5                  0            0
# 4                       3                 11                 11            0
# ...                   ...                ...                ...          ...
# 11425                   3                 11                 11            0
# 11426                   3                 10                  8            0
# 11427                   3                 15                 15            0
# 11428                   3                 22                  0            0
# 11429                   2                 12                 12            3
#
#        nb_hyperlinks  ratio_intHyperlinks  empty_title  domain_in_title
# 0                 17             0.529412            0                0  \
# 1                 30             0.966667            0                1
# 2                  4             1.000000            0                1
# 3                149             0.973154            0                1
# 4                102             0.470588            0                0
# ...              ...                  ...          ...              ...
# 11425            199             0.884422            0                0
# 11426              3             1.000000            0                1
# 11427             68             0.470588            0                0
# 11428             32             0.375000            0                1
# 11429             21             0.428571            0                1
#
#        page_rank
# 0              4
# 1              2
# 2              0
# 3              3
# 4              6
# ...          ...
# 11425          6
# 11426          0
# 11427         10
# 11428          4
# 11429          0
#
# [11430 rows x 21 columns]

# %%
X_selected.shape
# Out:
# (11430, 21)

# %%
y = original_dataset['status']
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 11425    0
# 11426    1
# 11427    0
# 11428    0
# 11429    1
# Name: status, Length: 11430, dtype: int64

# %% [markdown]
# #### 3.2 train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    shuffle = True)

# %% [markdown]
# ### 4. model fitting

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_random_forest = RandomForestClassifier(n_estimators=350,
                                             random_state=42,
                                            )

# %%
model_random_forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=350, random_state=42)

# %%
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score

def custom_accuracy_set (model, X_train, X_test, y_train, y_test, train=True):
    
    lb = preprocessing.LabelBinarizer()
    lb.fit(y_train)
    
    
    if train:
        x = X_train
        y = y_train
    elif not train:
        x = X_test
        y = y_test
        
    y_predicted = model.predict(x)
    
    accuracy = accuracy_score(y, y_predicted)
    print('model accuracy: {0:4f}'.format(accuracy))
    oconfusion_matrix = confusion_matrix(y, y_predicted)
    tn, fp, fn, tp = confusion_matrix(y, y_predicted).ravel()
    print('tn: {0:4f}, fp: {1:4f}, fn: {2:4f}, tp: {3:4f}'.format(tn, fp, fn, tp))
    print('fp rate: {0:4f}, fn rate: {1:4f}'.format(fp/(fp+tn), fn/(fn+tp)))
    print('Confusion matrix: \n {}'.format(oconfusion_matrix))
    oroc_auc_score = lb.transform(y), lb.transform(y_predicted)

# %% [markdown]
# ### 5. evaluating accuracy

# %%
# train accuracy

custom_accuracy_set(model_random_forest, X_train, X_test, y_train, y_test, train=True)
# Out:
# model accuracy: 1.000000
# tn: 4558.000000, fp: 0.000000, fn: 0.000000, tp: 4586.000000
# fp rate: 0.000000, fn rate: 0.000000
# Confusion matrix:
#  [[4558    0]
#  [   0 4586]]

# %%
# test accuracy

custom_accuracy_set(model_random_forest, X_train, X_test, y_train, y_test, train=False)
# Out:
# model accuracy: 0.952318
# tn: 1104.000000, fp: 53.000000, fn: 56.000000, tp: 1073.000000
# fp rate: 0.045808, fn rate: 0.049601
# Confusion matrix:
#  [[1104   53]
#  [  56 1073]]

# %% [markdown]
# ### 6. export the model

# %%
import pickle

with open('model_phishing_webpage_classifer','wb') as file:
    pickle.dump(model_random_forest,file)

# %%
# load model from file
print(X_test.iloc[0])
model_random_forest.predict(X_test)
# Out:
# length_url             35.000000
# length_hostname        11.000000
# ip                      0.000000
# nb_dots                 2.000000
# nb_qm                   0.000000
# nb_eq                   0.000000
# nb_slash                4.000000
# nb_www                  1.000000
# ratio_digits_url        0.000000
# ratio_digits_host       0.000000
# tld_in_subdomain        0.000000
# prefix_suffix           0.000000
# shortest_word_host      3.000000
# longest_words_raw       9.000000
# longest_word_path       9.000000
# phish_hints             0.000000
# nb_hyperlinks          97.000000
# ratio_intHyperlinks     0.969072
# empty_title             0.000000
# domain_in_title         1.000000
# page_rank               5.000000
# Name: 7529, dtype: float64
# array([0, 0, 0, ..., 1, 0, 1])
