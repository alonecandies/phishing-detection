# %%
"""
# _* coding: utf8 *_

filename: main.py

@author: sounishnath
createdAt: 2022-08-03 19:30:25
"""

from dataclasses import dataclass
from matplotlib import pyplot as plt

import seaborn as sns
import pandas as pd
from numpy import dtype
from sklearn import metrics, model_selection, preprocessing

import torch
import torch.nn as nn
import torch.utils.data

# %%
@dataclass
class Config:
    DATASET = "/kaggle/input/web-page-phishing-detection-dataset/dataset_phishing.csv"
    TARGET_COL = "status"
    DEVICE = "cpu"
    EPOCHS = 10
    TRAIN_BS = 1024
    VALID_BS = 1024
    LR = 3e-3

# %%
class Dataset:
    def __init__(self, data, target) -> None:
        self.data = data
        self.target = target

    def __len__(self):
        return len(self.data)

    def __getitem__(self, item):
        return dict(
            data=torch.tensor(self.data[item], dtype=torch.float),
            target=torch.tensor(self.target[item], dtype=torch.float),
        )

# %%
class Model(nn.Module):
    def __init__(self, n_inputs, hidden_units_1, hidden_units_2, n_outputs) -> None:
        super().__init__()
        self.pipeline1 = nn.Sequential(
            nn.Linear(n_inputs, hidden_units_1),
            nn.ReLU(),
            nn.BatchNorm1d(hidden_units_1),
            nn.Linear(hidden_units_1, hidden_units_1),
            nn.BatchNorm1d(hidden_units_1),
            nn.Dropout(0.20),
        )
        self.pipeline2 = nn.Sequential(
            nn.Linear(hidden_units_1, hidden_units_2),
            nn.ReLU(),
            nn.BatchNorm1d(hidden_units_2),
            nn.Linear(hidden_units_2, hidden_units_2),
            nn.ReLU(),
            nn.BatchNorm1d(hidden_units_2),
            nn.Dropout(0.20),
            nn.Linear(hidden_units_2, hidden_units_1),
        )
        self.output_pipeline = nn.Sequential(nn.Linear(hidden_units_1, n_outputs))

    def forward(self, data):
        out = self.pipeline1(data)
        out = self.pipeline2(out)
        out = self.output_pipeline(out)
        return out

# %%
class Engine:
    @staticmethod
    def train(epoch, model, dataset, criterion, optimizer, scheduler):
        model.to(Config.DEVICE)
        model.train()
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=Config.TRAIN_BS)
        losses = 0
        for batch_idx, tdata in enumerate(dataloader):
            data = tdata["data"].to(Config.DEVICE)
            target = tdata["target"].to(Config.DEVICE)
            output = model(data)
            optimizer.zero_grad()
            loss = criterion(output, target.view(-1, 1))
            com_metric = Engine.compute_metrics(output, target.view(-1, 1))
            losses += loss.item()
            loss.backward()
            optimizer.step()
            scheduler.step()

            print(
                "[train]: epoch:{0} batch:[{1}/{2}] loss:{3} metrics:{4} ".format(
                    epoch,
                    batch_idx,
                    len(dataloader),
                    (losses / len(dataloader)),
                    com_metric,
                )
            )

    @staticmethod
    def eval(epoch, model, dataset):
        print("---------- * --------------\n")
        model.to(Config.DEVICE)
        model.eval()
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=Config.VALID_BS)
        with torch.no_grad():
            for batch_idx, tdata in enumerate(dataloader):
                data = tdata["data"].to(Config.DEVICE)
                target = tdata["target"].to(Config.DEVICE)
                output = model(data)
                com_metric = Engine.compute_metrics(output, target.view(-1, 1))

                print(
                    "[valid]: epoch:{0} batch:[{1}/{2}] metrics:{3} ".format(
                        epoch,
                        batch_idx,
                        len(dataloader),
                        com_metric,
                    )
                )
            print("---------- * --------------\n")

    @staticmethod
    def generate_predictions(model, dataset, batch_size=1024):
        predictions = []
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
        with torch.no_grad():
            model.eval()
            for batch_idx, tdata in enumerate(dataloader):
                data = tdata["data"].to(Config.DEVICE)
                target = tdata["target"].to(Config.DEVICE)
                output = torch.sigmoid(model(data)).detach().cpu().numpy() >= 0.5
                predictions.extend(output)

        return predictions

    @staticmethod
    def compute_metrics(output, target=None):
        if target is None:
            return {}

        device = target.device.type
        output = torch.sigmoid(output).detach().cpu().numpy() >= 0.5
        target = target.detach().cpu().numpy()

        accuracy = metrics.accuracy_score(target, output)
        f1_score = metrics.f1_score(target, output)
        return dict(
            accuracy=torch.tensor(accuracy, device=device, dtype=torch.float32),
            f1_score=torch.tensor(f1_score, device=device, dtype=torch.float32),
        )

# %%
if __name__ == "__main__":
    dfx = pd.read_csv(Config.DATASET)
    cat_cols = [col for col in dfx.columns if dfx[col].dtype == "object"]
    print("cat_cols:", cat_cols)
    dfx["target"] = preprocessing.LabelEncoder().fit_transform(dfx[Config.TARGET_COL])
    print(dfx[[*cat_cols, "target"]].sample(5))
    df = dfx.drop(["url", "status"], axis=1)

    # corr = df.corr()
    # plt.imshow(corr, cmap="viridis", interpolation="nearest")
    # plt.colorbar()
    # plt.show()

    data = preprocessing.MinMaxScaler().fit_transform(
        df.drop(["target"], axis=1).values
    )
    targets = df["target"].values

    xtrain, xtest, ytrain, ytest = model_selection.train_test_split(
        data, targets, test_size=0.20, random_state=0, stratify=df["target"]
    )
    print(
        dict(
            xtrain_shape=xtrain.shape,
            xtest_shape=xtest.shape,
        )
    )

    train_dataset = Dataset(xtrain, ytrain)
    valid_dataset = Dataset(xtest, ytest)

    model = Model(
        n_inputs=data.shape[1], hidden_units_1=300, hidden_units_2=100, n_outputs=1
    )
    print(model)

    optimizer = torch.optim.Adam(model.parameters(), lr=Config.LR)
    schduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=0.78, gamma=0.3)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(Config.EPOCHS):
        Engine.train(
            epoch=epoch,
            model=model,
            dataset=train_dataset,
            criterion=criterion,
            optimizer=optimizer,
            scheduler=schduler,
        )
        Engine.eval(epoch=epoch, model=model, dataset=valid_dataset)
        torch.save(model, "model.bin")

    predictions = Engine.generate_predictions(model=model, dataset=valid_dataset)
    confus_mat = metrics.confusion_matrix(ytest, predictions)
    sns.heatmap(confus_mat, annot=True)
    plt.show()
# Out:
# cat_cols: ['url', 'status']
#                                                     url      status  target
# 6431  https://www.daniel-treufeld.de/wp-includes/css...    phishing       1
# 3434  http://support-appleld.com.secureupdate.duilaw...    phishing       1
# 3710                     http://www.harbor-cruises.com/  legitimate       0
# 4600                                http://cafca.com.mx  legitimate       0
# 2654            http://en.rfwiki.org/wiki/Image_scanner  legitimate       0
# {'xtrain_shape': (9144, 87), 'xtest_shape': (2286, 87)}
# Model(
#   (pipeline1): Sequential(
#     (0): Linear(in_features=87, out_features=300, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=300, out_features=300, bias=True)
#     (4): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): Dropout(p=0.2, inplace=False)
#   )
#   (pipeline2): Sequential(
#     (0): Linear(in_features=300, out_features=100, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=100, out_features=100, bias=True)
#     (4): ReLU()
#     (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout(p=0.2, inplace=False)
#     (7): Linear(in_features=100, out_features=300, bias=True)
#   )
#   (output_pipeline): Sequential(
#     (0): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# [train]: epoch:0 batch:[0/9] loss:0.07493342293633355 metrics:{'accuracy': tensor(0.5781), 'f1_score': tensor(0.5963)}
# [train]: epoch:0 batch:[1/9] loss:0.12076511647966173 metrics:{'accuracy': tensor(0.8701), 'f1_score': tensor(0.8684)}
# [train]: epoch:0 batch:[2/9] loss:0.14960264828470018 metrics:{'accuracy': tensor(0.8984), 'f1_score': tensor(0.8996)}
# [train]: epoch:0 batch:[3/9] loss:0.1771101885371738 metrics:{'accuracy': tensor(0.8984), 'f1_score': tensor(0.8972)}
# [train]: epoch:0 batch:[4/9] loss:0.20379144781165653 metrics:{'accuracy': tensor(0.9150), 'f1_score': tensor(0.9185)}
# [train]: epoch:0 batch:[5/9] loss:0.2312684870428509 metrics:{'accuracy': tensor(0.9014), 'f1_score': tensor(0.8966)}
# [train]: epoch:0 batch:[6/9] loss:0.2495087335507075 metrics:{'accuracy': tensor(0.9453), 'f1_score': tensor(0.9452)}
# [train]: epoch:0 batch:[7/9] loss:0.27116603321499294 metrics:{'accuracy': tensor(0.9268), 'f1_score': tensor(0.9268)}
# [train]: epoch:0 batch:[8/9] loss:0.28596632844871944 metrics:{'accuracy': tensor(0.9538), 'f1_score': tensor(0.9534)}
# ---------- * --------------
#
# [valid]: epoch:0 batch:[0/3] metrics:{'accuracy': tensor(0.9131), 'f1_score': tensor(0.9050)}
# [valid]: epoch:0 batch:[1/3] metrics:{'accuracy': tensor(0.9004), 'f1_score': tensor(0.8931)}
# [valid]: epoch:0 batch:[2/3] metrics:{'accuracy': tensor(0.8613), 'f1_score': tensor(0.8465)}
# ---------- * --------------
#
# [train]: epoch:1 batch:[0/9] loss:0.021844451626141865 metrics:{'accuracy': tensor(0.9346), 'f1_score': tensor(0.9339)}
# [train]: epoch:1 batch:[1/9] loss:0.040825102064344615 metrics:{'accuracy': tensor(0.9385), 'f1_score': tensor(0.9396)}
# [train]: epoch:1 batch:[2/9] loss:0.056660792893833585 metrics:{'accuracy': tensor(0.9541), 'f1_score': tensor(0.9547)}
# [train]: epoch:1 batch:[3/9] loss:0.07315842310587566 metrics:{'accuracy': tensor(0.9463), 'f1_score': tensor(0.9453)}
# [train]: epoch:1 batch:[4/9] loss:0.09093857473797268 metrics:{'accuracy': tensor(0.9463), 'f1_score': tensor(0.9487)}
# [train]: epoch:1 batch:[5/9] loss:0.10788538389735752 metrics:{'accuracy': tensor(0.9463), 'f1_score': tensor(0.9442)}
# [train]: epoch:1 batch:[6/9] loss:0.1205153837800026 metrics:{'accuracy': tensor(0.9600), 'f1_score': tensor(0.9599)}
# [train]: epoch:1 batch:[7/9] loss:0.13612313154670927 metrics:{'accuracy': tensor(0.9482), 'f1_score': tensor(0.9476)}
# [train]: epoch:1 batch:[8/9] loss:0.1481491360399458 metrics:{'accuracy': tensor(0.9664), 'f1_score': tensor(0.9656)}
# ---------- * --------------
#
# [valid]: epoch:1 batch:[0/3] metrics:{'accuracy': tensor(0.9053), 'f1_score': tensor(0.8956)}
# [valid]: epoch:1 batch:[1/3] metrics:{'accuracy': tensor(0.9072), 'f1_score': tensor(0.9005)}
# [valid]: epoch:1 batch:[2/3] metrics:{'accuracy': tensor(0.8571), 'f1_score': tensor(0.8381)}
# ---------- * --------------
#
# [train]: epoch:2 batch:[0/9] loss:0.015999457902378507 metrics:{'accuracy': tensor(0.9463), 'f1_score': tensor(0.9449)}
# [train]: epoch:2 batch:[1/9] loss:0.030307215121057298 metrics:{'accuracy': tensor(0.9482), 'f1_score': tensor(0.9491)}
# [train]: epoch:2 batch:[2/9] loss:0.04221884161233902 metrics:{'accuracy': tensor(0.9561), 'f1_score': tensor(0.9564)}
# [train]: epoch:2 batch:[3/9] loss:0.0549402998553382 metrics:{'accuracy': tensor(0.9570), 'f1_score': tensor(0.9565)}
# [train]: epoch:2 batch:[4/9] loss:0.06850119597382015 metrics:{'accuracy': tensor(0.9619), 'f1_score': tensor(0.9637)}
# [train]: epoch:2 batch:[5/9] loss:0.08413207530975342 metrics:{'accuracy': tensor(0.9443), 'f1_score': tensor(0.9422)}
# [train]: epoch:2 batch:[6/9] loss:0.09496394213702944 metrics:{'accuracy': tensor(0.9658), 'f1_score': tensor(0.9660)}
# [train]: epoch:2 batch:[7/9] loss:0.10713543246189754 metrics:{'accuracy': tensor(0.9580), 'f1_score': tensor(0.9583)}
# [train]: epoch:2 batch:[8/9] loss:0.11651457349459331 metrics:{'accuracy': tensor(0.9727), 'f1_score': tensor(0.9720)}
# ---------- * --------------
#
# [valid]: epoch:2 batch:[0/3] metrics:{'accuracy': tensor(0.9209), 'f1_score': tensor(0.9137)}
# [valid]: epoch:2 batch:[1/3] metrics:{'accuracy': tensor(0.9199), 'f1_score': tensor(0.9149)}
# [valid]: epoch:2 batch:[2/3] metrics:{'accuracy': tensor(0.8739), 'f1_score': tensor(0.8598)}
# ---------- * --------------
#
# [train]: epoch:3 batch:[0/9] loss:0.01340597371260325 metrics:{'accuracy': tensor(0.9512), 'f1_score': tensor(0.9496)}
# [train]: epoch:3 batch:[1/9] loss:0.02561852004792955 metrics:{'accuracy': tensor(0.9590), 'f1_score': tensor(0.9597)}
# [train]: epoch:3 batch:[2/9] loss:0.036148486038049064 metrics:{'accuracy': tensor(0.9619), 'f1_score': tensor(0.9620)}
# [train]: epoch:3 batch:[3/9] loss:0.047427731255690254 metrics:{'accuracy': tensor(0.9678), 'f1_score': tensor(0.9673)}
# [train]: epoch:3 batch:[4/9] loss:0.05884807474083371 metrics:{'accuracy': tensor(0.9629), 'f1_score': tensor(0.9646)}
# [train]: epoch:3 batch:[5/9] loss:0.07026432785722944 metrics:{'accuracy': tensor(0.9639), 'f1_score': tensor(0.9621)}
# [train]: epoch:3 batch:[6/9] loss:0.07952545252111223 metrics:{'accuracy': tensor(0.9707), 'f1_score': tensor(0.9708)}
# [train]: epoch:3 batch:[7/9] loss:0.08937386340565151 metrics:{'accuracy': tensor(0.9639), 'f1_score': tensor(0.9638)}
# [train]: epoch:3 batch:[8/9] loss:0.09744616515106624 metrics:{'accuracy': tensor(0.9758), 'f1_score': tensor(0.9753)}
# ---------- * --------------
#
# [valid]: epoch:3 batch:[0/3] metrics:{'accuracy': tensor(0.9521), 'f1_score': tensor(0.9504)}
# [valid]: epoch:3 batch:[1/3] metrics:{'accuracy': tensor(0.9424), 'f1_score': tensor(0.9413)}
# [valid]: epoch:3 batch:[2/3] metrics:{'accuracy': tensor(0.9202), 'f1_score': tensor(0.9170)}
# ---------- * --------------
#
# [train]: epoch:4 batch:[0/9] loss:0.012222692370414734 metrics:{'accuracy': tensor(0.9609), 'f1_score': tensor(0.9602)}
# [train]: epoch:4 batch:[1/9] loss:0.02132280833191342 metrics:{'accuracy': tensor(0.9727), 'f1_score': tensor(0.9733)}
# [train]: epoch:4 batch:[2/9] loss:0.028821336726347607 metrics:{'accuracy': tensor(0.9756), 'f1_score': tensor(0.9758)}
# [train]: epoch:4 batch:[3/9] loss:0.037098328272501625 metrics:{'accuracy': tensor(0.9756), 'f1_score': tensor(0.9752)}
# [train]: epoch:4 batch:[4/9] loss:0.0459561405910386 metrics:{'accuracy': tensor(0.9736), 'f1_score': tensor(0.9750)}
# [train]: epoch:4 batch:[5/9] loss:0.05546582655774222 metrics:{'accuracy': tensor(0.9697), 'f1_score': tensor(0.9679)}
# [train]: epoch:4 batch:[6/9] loss:0.06339834216568205 metrics:{'accuracy': tensor(0.9717), 'f1_score': tensor(0.9716)}
# [train]: epoch:4 batch:[7/9] loss:0.0720892565117942 metrics:{'accuracy': tensor(0.9736), 'f1_score': tensor(0.9737)}
# [train]: epoch:4 batch:[8/9] loss:0.07828912097546789 metrics:{'accuracy': tensor(0.9800), 'f1_score': tensor(0.9797)}
# ---------- * --------------
#
# [valid]: epoch:4 batch:[0/3] metrics:{'accuracy': tensor(0.9531), 'f1_score': tensor(0.9510)}
# [valid]: epoch:4 batch:[1/3] metrics:{'accuracy': tensor(0.9355), 'f1_score': tensor(0.9337)}
# [valid]: epoch:4 batch:[2/3] metrics:{'accuracy': tensor(0.9160), 'f1_score': tensor(0.9123)}
# ---------- * --------------
#
# [train]: epoch:5 batch:[0/9] loss:0.008996329373783536 metrics:{'accuracy': tensor(0.9678), 'f1_score': tensor(0.9670)}
# [train]: epoch:5 batch:[1/9] loss:0.016396345363722906 metrics:{'accuracy': tensor(0.9766), 'f1_score': tensor(0.9771)}
# [train]: epoch:5 batch:[2/9] loss:0.021398420963022444 metrics:{'accuracy': tensor(0.9834), 'f1_score': tensor(0.9836)}
# [train]: epoch:5 batch:[3/9] loss:0.027960788044664595 metrics:{'accuracy': tensor(0.9775), 'f1_score': tensor(0.9773)}
# [train]: epoch:5 batch:[4/9] loss:0.03532663815551334 metrics:{'accuracy': tensor(0.9746), 'f1_score': tensor(0.9760)}
# [train]: epoch:5 batch:[5/9] loss:0.04274049484067493 metrics:{'accuracy': tensor(0.9727), 'f1_score': tensor(0.9711)}
# [train]: epoch:5 batch:[6/9] loss:0.04898021825485759 metrics:{'accuracy': tensor(0.9775), 'f1_score': tensor(0.9776)}
# [train]: epoch:5 batch:[7/9] loss:0.054889304356442556 metrics:{'accuracy': tensor(0.9785), 'f1_score': tensor(0.9786)}
# [train]: epoch:5 batch:[8/9] loss:0.060986226631535426 metrics:{'accuracy': tensor(0.9842), 'f1_score': tensor(0.9840)}
# ---------- * --------------
#
# [valid]: epoch:5 batch:[0/3] metrics:{'accuracy': tensor(0.9639), 'f1_score': tensor(0.9627)}
# [valid]: epoch:5 batch:[1/3] metrics:{'accuracy': tensor(0.9561), 'f1_score': tensor(0.9558)}
# [valid]: epoch:5 batch:[2/3] metrics:{'accuracy': tensor(0.9412), 'f1_score': tensor(0.9407)}
# ---------- * --------------
#
# [train]: epoch:6 batch:[0/9] loss:0.00775944772693846 metrics:{'accuracy': tensor(0.9795), 'f1_score': tensor(0.9792)}
# [train]: epoch:6 batch:[1/9] loss:0.013681265629000135 metrics:{'accuracy': tensor(0.9775), 'f1_score': tensor(0.9781)}
# [train]: epoch:6 batch:[2/9] loss:0.018980787446101505 metrics:{'accuracy': tensor(0.9824), 'f1_score': tensor(0.9826)}
# [train]: epoch:6 batch:[3/9] loss:0.0250564892258909 metrics:{'accuracy': tensor(0.9805), 'f1_score': tensor(0.9800)}
# [train]: epoch:6 batch:[4/9] loss:0.03168541565537453 metrics:{'accuracy': tensor(0.9785), 'f1_score': tensor(0.9795)}
# [train]: epoch:6 batch:[5/9] loss:0.03659269668989711 metrics:{'accuracy': tensor(0.9854), 'f1_score': tensor(0.9844)}
# [train]: epoch:6 batch:[6/9] loss:0.040881078276369304 metrics:{'accuracy': tensor(0.9854), 'f1_score': tensor(0.9853)}
# [train]: epoch:6 batch:[7/9] loss:0.04779128026631144 metrics:{'accuracy': tensor(0.9736), 'f1_score': tensor(0.9739)}
# [train]: epoch:6 batch:[8/9] loss:0.05456106157766448 metrics:{'accuracy': tensor(0.9811), 'f1_score': tensor(0.9810)}
# ---------- * --------------
#
# [valid]: epoch:6 batch:[0/3] metrics:{'accuracy': tensor(0.9619), 'f1_score': tensor(0.9614)}
# [valid]: epoch:6 batch:[1/3] metrics:{'accuracy': tensor(0.9561), 'f1_score': tensor(0.9563)}
# [valid]: epoch:6 batch:[2/3] metrics:{'accuracy': tensor(0.9496), 'f1_score': tensor(0.9500)}
# ---------- * --------------
#
# [train]: epoch:7 batch:[0/9] loss:0.008388192289405398 metrics:{'accuracy': tensor(0.9766), 'f1_score': tensor(0.9765)}
# [train]: epoch:7 batch:[1/9] loss:0.012555310295687782 metrics:{'accuracy': tensor(0.9863), 'f1_score': tensor(0.9867)}
# [train]: epoch:7 batch:[2/9] loss:0.01746935521562894 metrics:{'accuracy': tensor(0.9805), 'f1_score': tensor(0.9807)}
# [train]: epoch:7 batch:[3/9] loss:0.024801873084571626 metrics:{'accuracy': tensor(0.9736), 'f1_score': tensor(0.9729)}
# [train]: epoch:7 batch:[4/9] loss:0.03156660952501827 metrics:{'accuracy': tensor(0.9805), 'f1_score': tensor(0.9813)}
# [train]: epoch:7 batch:[5/9] loss:0.03636319521400663 metrics:{'accuracy': tensor(0.9854), 'f1_score': tensor(0.9843)}
# [train]: epoch:7 batch:[6/9] loss:0.04137910240226322 metrics:{'accuracy': tensor(0.9873), 'f1_score': tensor(0.9873)}
# [train]: epoch:7 batch:[7/9] loss:0.047773710969421596 metrics:{'accuracy': tensor(0.9756), 'f1_score': tensor(0.9757)}
# [train]: epoch:7 batch:[8/9] loss:0.05398966578973664 metrics:{'accuracy': tensor(0.9790), 'f1_score': tensor(0.9788)}
# ---------- * --------------
#
# [valid]: epoch:7 batch:[0/3] metrics:{'accuracy': tensor(0.9561), 'f1_score': tensor(0.9558)}
# [valid]: epoch:7 batch:[1/3] metrics:{'accuracy': tensor(0.9492), 'f1_score': tensor(0.9501)}
# [valid]: epoch:7 batch:[2/3] metrics:{'accuracy': tensor(0.9328), 'f1_score': tensor(0.9328)}
# ---------- * --------------
#
# [train]: epoch:8 batch:[0/9] loss:0.009687543743186526 metrics:{'accuracy': tensor(0.9697), 'f1_score': tensor(0.9698)}
# [train]: epoch:8 batch:[1/9] loss:0.014434433645672269 metrics:{'accuracy': tensor(0.9844), 'f1_score': tensor(0.9849)}
# [train]: epoch:8 batch:[2/9] loss:0.01953814923763275 metrics:{'accuracy': tensor(0.9795), 'f1_score': tensor(0.9800)}
# [train]: epoch:8 batch:[3/9] loss:0.025299416648017034 metrics:{'accuracy': tensor(0.9785), 'f1_score': tensor(0.9783)}
# [train]: epoch:8 batch:[4/9] loss:0.036102106173833214 metrics:{'accuracy': tensor(0.9717), 'f1_score': tensor(0.9730)}
# [train]: epoch:8 batch:[5/9] loss:0.04203765425417158 metrics:{'accuracy': tensor(0.9795), 'f1_score': tensor(0.9778)}
# [train]: epoch:8 batch:[6/9] loss:0.04903662453095118 metrics:{'accuracy': tensor(0.9746), 'f1_score': tensor(0.9743)}
# [train]: epoch:8 batch:[7/9] loss:0.05459479159779019 metrics:{'accuracy': tensor(0.9795), 'f1_score': tensor(0.9791)}
# [train]: epoch:8 batch:[8/9] loss:0.06072182125515408 metrics:{'accuracy': tensor(0.9811), 'f1_score': tensor(0.9807)}
# ---------- * --------------
#
# [valid]: epoch:8 batch:[0/3] metrics:{'accuracy': tensor(0.9570), 'f1_score': tensor(0.9562)}
# [valid]: epoch:8 batch:[1/3] metrics:{'accuracy': tensor(0.9404), 'f1_score': tensor(0.9408)}
# [valid]: epoch:8 batch:[2/3] metrics:{'accuracy': tensor(0.9244), 'f1_score': tensor(0.9231)}
# ---------- * --------------
#
# [train]: epoch:9 batch:[0/9] loss:0.008750260704093508 metrics:{'accuracy': tensor(0.9707), 'f1_score': tensor(0.9706)}
# [train]: epoch:9 batch:[1/9] loss:0.015153294636143578 metrics:{'accuracy': tensor(0.9785), 'f1_score': tensor(0.9793)}
# [train]: epoch:9 batch:[2/9] loss:0.021158241149451997 metrics:{'accuracy': tensor(0.9766), 'f1_score': tensor(0.9771)}
# [train]: epoch:9 batch:[3/9] loss:0.028249809725417033 metrics:{'accuracy': tensor(0.9746), 'f1_score': tensor(0.9745)}
# [train]: epoch:9 batch:[4/9] loss:0.03394951381617122 metrics:{'accuracy': tensor(0.9854), 'f1_score': tensor(0.9862)}
# [train]: epoch:9 batch:[5/9] loss:0.040385499596595764 metrics:{'accuracy': tensor(0.9736), 'f1_score': tensor(0.9723)}
# [train]: epoch:9 batch:[6/9] loss:0.045571078856786094 metrics:{'accuracy': tensor(0.9824), 'f1_score': tensor(0.9824)}
# [train]: epoch:9 batch:[7/9] loss:0.05204185512330797 metrics:{'accuracy': tensor(0.9736), 'f1_score': tensor(0.9735)}
# [train]: epoch:9 batch:[8/9] loss:0.058308002849419914 metrics:{'accuracy': tensor(0.9800), 'f1_score': tensor(0.9795)}
# ---------- * --------------
#
# [valid]: epoch:9 batch:[0/3] metrics:{'accuracy': tensor(0.9658), 'f1_score': tensor(0.9649)}
# [valid]: epoch:9 batch:[1/3] metrics:{'accuracy': tensor(0.9502), 'f1_score': tensor(0.9505)}
# [valid]: epoch:9 batch:[2/3] metrics:{'accuracy': tensor(0.9370), 'f1_score': tensor(0.9367)}
# ---------- * --------------
